# %% [markdown]
# # NPL - First steps with Natural Language Took Kit (NLTK)

# %%
# %pylab
# %matplotlib inline

# %config InlineBackend.figure_format = 'retina'

import numpy as np
# Out:
# Using matplotlib backend: Qt5Agg
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### Import NLTK

# %% [markdown]
# At the beginning, we are going to import NLTK and download all its packages:

# %%
import nltk
#nltk.download() #Execute if it is not downloaded

# %% [markdown]
# ### 1. Create a input text for our NLP chain

# %%
# 1. Create a input text for our NLP chain
text = "I didn't notice my animals were uglier than yours! I'm sorry..."
print ("1. Text:",text)
# Out:
# 1. Text: I didn't notice my animals were uglier than yours! I'm sorry...

# %% [markdown]
# ### 2. Split the text on sentences (optional)

# %%
# 2. Split the text on sentences (optional)
sentences = nltk.tokenize.sent_tokenize(text)
print ("2. Sentences:",sentences)
# Out:
# 2. Sentences: ["I didn't notice my animals were uglier than yours!", "I'm sorry..."]

# %% [markdown]
# ### 3. Tokenization: Tokenize the text, i.e: split the text on tokens

# %%
# 3. Tokenization: Tokenize the text, i.e: split the text on tokens
tokens = nltk.word_tokenize(text)
print ("3. Tokens:",tokens)
# Out:
# 3. Tokens: ['I', 'did', "n't", 'notice', 'my', 'animals', 'were', 'uglier', 'than', 'yours', '!', 'I', "'m", 'sorry', '...']

# %% [markdown]
# ### 4. Morphology/Lexical analysis: using Penn Tree Bank POS tags

# %% [markdown]
# First, we load the Penn Tree Bank POS tags in a `csv` file, because like this we can know what it means each tag:

# %%
import pandas as pd

peen_tree_bank = pd.read_csv("data/ref_nlp_penn_treebank2_pos_tags.csv", sep = ",")
peen_tree_bank
# Out:
#     penn_treebank_pos_locator penn_treebank_tag  \
# 0                           1                CC
# 1                           2                CD
# 2                           3                DT
# 3                           4                EX
# 4                           5                FW
# 5                           6                IN
# 6                           7                JJ
# 7                           8               JJR
# 8                           9               JJS
# 9                          10                LS
# 10                         11                MD
# 11                         12                NN
# 12                         13               NNS
# 13                         14               NNP
# 14                         15              NNPS
# 15                         16               PDT
# 16                         17               POS
# 17                         18               PRP
# 18                         19              PRP$
# 19                         20                RB
# 20                         21               RBR
# 21                         22               RBS
# 22                         23                RP
# 23                         24               SYM
# 24                         25                TO
# 25                         26                UH
# 26                         27                VB
# 27                         28               VBZ
# 28                         29               VBP
# 29                         30               VBD
# 30                         31               VBN
# 31                         32               VBG
# 32                         33               WDT
# 33                         34                WP
# 34                         35               WP$
# 35                         36               WRB
# 36                         37                 .
# 37                         38                 ,
# 38                         39                 :
# 39                         40                 (
# 40                         41                 )
# 41                         42                 $
# 42                         43                ``
# 43                         44                ''
#
#                               tag_description  \
# 0                   conjunction, coordinating
# 1                             cardinal number
# 2                                  determiner
# 3                           existential there
# 4                                foreign word
# 5   conjunction, subordinating or preposition
# 6                                   adjective
# 7                      adjective, comparative
# 8                      adjective, superlative
# 9                            list item marker
# 10                      verb, modal auxillary
# 11                     noun, singular or mass
# 12                               noun, plural
# 13                      noun, proper singular
# 14                        noun, proper plural
# 15                              predeterminer
# 16                          possessive ending
# 17                          pronoun, personal
# 18                        pronoun, possessive
# 19                                     adverb
# 20                        adverb, comparative
# 21                        adverb, superlative
# 22                           adverb, particle
# 23                                     symbol
# 24                             infinitival to
# 25                               interjection
# 26                            verb, base form
# 27          verb, 3rd person singular present
# 28      verb, non-3rd person singular present
# 29                           verb, past tense
# 30                      verb, past participle
# 31         verb, gerund or present participle
# 32                              wh-determiner
# 33                       wh-pronoun, personal
# 34                     wh-pronoun, possessive
# 35                                  wh-adverb
# 36          punctuation mark, sentence closer
# 37                    punctuation mark, comma
# 38                    punctuation mark, colon
# 39           contextual separator, left paren
# 40          contextual separator, right paren
# 41                                     dollar
# 42                     opening quotation mark
# 43                     closing quotation mark
#
#                               example_text
# 0                             and, or, but
# 1                         five, three, 13%
# 2                           the, a, these
# 3                     there were six boys
# 4                                    mais
# 5                  of, on, before, unless
# 6                               nice, easy
# 7                            nicer, easier
# 8                         nicest, easiest
# 9                                      NaN
# 10                            may, should
# 11                 tiger, chair, laughter
# 12                tigers, chairs, insects
# 13                    Germany, God, Alice
# 14             we met two Christmases ago
# 15                      both his children
# 16                                      's
# 17                            me, you, it
# 18                          my, your, our
# 19               extremely, loudly, hard
# 20                                 better
# 21                                   best
# 22                         about, off, up
# 23                                      %
# 24                            what to do?
# 25                         oh, oops, gosh
# 26                                  think
# 27                             she thinks
# 28                                I think
# 29                           they thought
# 30                          a sunken ship
# 31                        thinking is fun
# 32             which, whatever, whichever
# 33                        what, who, whom
# 34                        whose, whosever
# 35                            where, when
# 36                                   .;?*
# 37                                      ,
# 38                                      :
# 39                                      (
# 40                                      )
# 41  $ -$ --$ A$ C$ HK$ M$ NZ$ S$ U.S.$ US$
# 42                                    ` ``
# 43                                    ' ''

# %%
# 4. Morphology/Lexical analysis: set a morphology tag for each token
tagged = nltk.pos_tag(tokens)
print ("4. Analisis Morfologico:",tagged)
# Out:
# 4. Analisis Morfologico: [('I', 'PRP'), ('did', 'VBD'), ("n't", 'RB'), ('notice', 'VB'), ('my', 'PRP$'), ('animals', 'NNS'), ('were', 'VBD'), ('uglier', 'JJR'), ('than', 'IN'), ('yours', 'JJR'), ('!', '.'), ('I', 'PRP'), ("'m", 'VBP'), ('sorry', 'JJ'), ('...', ':')]

# %% [markdown]
# ### 5. Stemming: get the stem of each token

# %%
# 5. Stemming: get the stem of each token. For Stemming, the morphology analysis is not necessary.
from nltk.stem import PorterStemmer

stemmer = PorterStemmer()
print ("5. Stems: ")
for tok in tokens:
    print (stemmer.stem(tok.lower()))
# Out:
# 5. Stems:
# i
# did
# n't
# notic
# my
# anim
# were
# uglier
# than
# your
# !
# i
# 'm
# sorri
# ...

# %% [markdown]
# ### 6. Lemmatization: get the lemma of each token

# %%
from nltk.stem import WordNetLemmatizer 
from nltk.corpus import wordnet

# Create the lemmatizer
lemmatizer = WordNetLemmatizer()

# WordNetLemmatizer only knows 4 POS tags: a (adjetive), r (adverb), n (noun) and v (verb)
# For that, we should convert Penn Tree Bank format to WordNet format 
# (e.g: N->n, J->a, R->r, V->V, ...)

wnTags = {'N':wordnet.NOUN, 'J':wordnet.ADJ, 'V':wordnet.VERB, 'R':wordnet.ADV} 

print ("6. Lemmas: ")
# For each token and its tag:
for (tok,tag) in tagged:
    # WordNet has not the short forms: 'm, n't, so we should introduce them for the good lemmatization
    if tok=='\'m':
        tok = 'am'
    if tok=='\'s':
        tok = 'is'
    if tok=='n\'t':
        tok = 'not'
        
    # We only get the first char of the tag because we use it to convert it to WordNet format
    tag = tag[:1]
    
    # Lemmatize the tokens
    lemma = lemmatizer.lemmatize(tok.lower(), wnTags.get(tag, wordnet.NOUN))

    # Other alternative for get the lemma can be use the wordnet.morphy() function 
    #lemma = wordnet.morphy(tok.lower(), wnTags.get(tag, wordnet.NOUN))
    
    
    if lemma is None: #Si wordnet no contiene la palabra, supondremos que el lema es igual al token
       lemma = tok.lower() 
    print (lemma)
# Out:
# 6. Lemmas:
# i
# do
# not
# notice
# my
# animal
# be
# ugly
# than
# yours
# !
# i
# be
# sorry
# ...

# %% [markdown]
# ### 7. Syntactic analysis

# %%
# Let's start with a sentence of a Groucho Marx's known text, with ambiguity
# "While hunting in Africa, I shot an elephant in my pijamas. How he got into my pijamas, I don't know."
sent = ['I', 'shot', 'an', 'elephant', 'in', 'my', 'pijamas']

# Create our CFG
grammar = nltk.CFG.fromstring("""
S -> NP VP
PP -> P NP
NP -> Det N | Det N PP | 'I'
VP -> V NP | VP PP
Det -> 'an' | 'my'
N -> 'elephant' | 'pijamas'
V -> 'shot' | 'did'
P -> 'in'
""")


# Generate a syntactic parser be able to recognize the grammar
parser = nltk.ChartParser(grammar, trace=1)
print ('7. Syntactic analysis:\n')
for tree in parser.parse(sent):
    print(tree,'\n')
    tree.draw()
# Out:
# 7. Syntactic analysis:
#
# |.  I  . shot.  an .eleph.  in .  my .pijam.|
# |[-----]     .     .     .     .     .     .| [0:1] 'I'
# |.     [-----]     .     .     .     .     .| [1:2] 'shot'
# |.     .     [-----]     .     .     .     .| [2:3] 'an'
# |.     .     .     [-----]     .     .     .| [3:4] 'elephant'
# |.     .     .     .     [-----]     .     .| [4:5] 'in'
# |.     .     .     .     .     [-----]     .| [5:6] 'my'
# |.     .     .     .     .     .     [-----]| [6:7] 'pijamas'
# |[-----]     .     .     .     .     .     .| [0:1] NP -> 'I' *
# |[----->     .     .     .     .     .     .| [0:1] S  -> NP * VP
# |.     [-----]     .     .     .     .     .| [1:2] V  -> 'shot' *
# |.     [----->     .     .     .     .     .| [1:2] VP -> V * NP
# |.     .     [-----]     .     .     .     .| [2:3] Det -> 'an' *
# |.     .     [----->     .     .     .     .| [2:3] NP -> Det * N
# |.     .     [----->     .     .     .     .| [2:3] NP -> Det * N PP
# |.     .     .     [-----]     .     .     .| [3:4] N  -> 'elephant' *
# |.     .     [-----------]     .     .     .| [2:4] NP -> Det N *
# |.     .     [----------->     .     .     .| [2:4] NP -> Det N * PP
# |.     .     [----------->     .     .     .| [2:4] S  -> NP * VP
# |.     [-----------------]     .     .     .| [1:4] VP -> V NP *
# |.     [----------------->     .     .     .| [1:4] VP -> VP * PP
# |[-----------------------]     .     .     .| [0:4] S  -> NP VP *
# |.     .     .     .     [-----]     .     .| [4:5] P  -> 'in' *
# |.     .     .     .     [----->     .     .| [4:5] PP -> P * NP
# |.     .     .     .     .     [-----]     .| [5:6] Det -> 'my' *
# |.     .     .     .     .     [----->     .| [5:6] NP -> Det * N
# |.     .     .     .     .     [----->     .| [5:6] NP -> Det * N PP
# |.     .     .     .     .     .     [-----]| [6:7] N  -> 'pijamas' *
# |.     .     .     .     .     [-----------]| [5:7] NP -> Det N *
# |.     .     .     .     .     [----------->| [5:7] NP -> Det N * PP
# |.     .     .     .     .     [----------->| [5:7] S  -> NP * VP
# |.     .     .     .     [-----------------]| [4:7] PP -> P NP *
# |.     .     [-----------------------------]| [2:7] NP -> Det N PP *
# |.     [-----------------------------------]| [1:7] VP -> VP PP *
# |.     [----------------------------------->| [1:7] VP -> VP * PP
# |[=========================================]| [0:7] S  -> NP VP *
# |.     .     [----------------------------->| [2:7] S  -> NP * VP
# |.     [-----------------------------------]| [1:7] VP -> V NP *
# |.     [----------------------------------->| [1:7] VP -> VP * PP
# |[=========================================]| [0:7] S  -> NP VP *
# (S
#   (NP I)
#   (VP
#     (VP (V shot) (NP (Det an) (N elephant)))
#     (PP (P in) (NP (Det my) (N pijamas)))))
#
# (S
#   (NP I)
#   (VP
#     (V shot)
#     (NP (Det an) (N elephant) (PP (P in) (NP (Det my) (N pijamas))))))
